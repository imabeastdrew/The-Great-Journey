# %%
import pandas as pd

# %%
df = pd.read_csv('stackoverflowdata2024/survey_results_public.csv')
df2 = pd.read_csv('stackoverflowdata2024/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 114)
pd.set_option('display.max_rows', 87)

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
df2.head()
# Out:
#       qid       qname                                           question  \
# 0    QID2  MainBranch  Which of the following options best describes ...
# 1  QID127         Age                                 What is your age?*
# 2  QID296  Employment  Which of the following best describes your cur...
# 3  QID308  RemoteWork  Which best describes your current work situation?
# 4  QID341       Check  Just checking to make sure you are paying atte...
#
#   force_resp type selector
# 0       True   MC     SAVR
# 1       True   MC     SAVR
# 2       True   MC     MAVR
# 3      False   MC     SAVR
# 4       True   MC     SAVR

# %%
df.shape
# Out:
# (65437, 114)

# %%
df2.shape
# Out:
# (87, 6)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
df[["Age", "Employment"]]
# would return a series if only "age" was inputted, but returns a filtered
# down dataframe because there are two series objects
# Out:
#                       Age           Employment
# 0      Under 18 years old  Employed, full-time
# 1         35-44 years old  Employed, full-time
# 2         45-54 years old  Employed, full-time
# 3         18-24 years old   Student, full-time
# 4         18-24 years old   Student, full-time
# ...                   ...                  ...
# 65432     18-24 years old  Employed, full-time
# 65433     25-34 years old  Employed, full-time
# 65434     25-34 years old  Employed, full-time
# 65435     18-24 years old  Employed, full-time
# 65436     18-24 years old   Student, full-time
#
# [65437 rows x 2 columns]

# %%
df[["Age", "Employment"]].value_counts()
# Out:
# Age                Employment
# 25-34 years old    Employed, full-time                                                                                     17282
# 35-44 years old    Employed, full-time                                                                                     10775
# 18-24 years old    Employed, full-time                                                                                      4839
# 45-54 years old    Employed, full-time                                                                                      4234
# 18-24 years old    Student, full-time                                                                                       2967
#                                                                                                                            ...
# 65 years or older  Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Retired         1
# ...

# %%
df.loc[[0,30,86], ["MainBranch", "Age"]]
# we specefy the row name with loc, but since the row names are indexes
# we pass in integers. Then we pass in column names.
# we end up with a filtered-down dataframe instead of a series
# Out:
#                         MainBranch                 Age
# 0   I am a developer by profession  Under 18 years old
# 30  I am a developer by profession   Prefer not to say
# 86  I am a developer by profession     45-54 years old

# %%
df.loc[[3,73,1000],"Age"]
# this returns a series instead of a filtered-down dataframe
# Out:
# 3       18-24 years old
# 73      35-44 years old
# 1000    35-44 years old
# Name: Age, dtype: object

# %%
df.loc[5:9, "Age":"Check"]
# we can slice as well, but you do not wrap in brackets. this returns 5,6,7,8,9
# "Age" , "Employment" , "RemoteWork" , "Check"
# this returns a filtered-down dataframe
# Out:
#                   Age                                         Employment  \
# 5  Under 18 years old                                 Student, full-time
# 6     35-44 years old                                Employed, full-time
# 7     18-24 years old  Student, full-time;Not employed, but looking f...
# 8     45-54 years old                                Employed, full-time
# 9     35-44 years old  Independent contractor, freelancer, or self-em...
#
#   RemoteWork   Check
# 5        NaN  Apples
# 6     Remote  Apples
# 7        NaN  Apples
# 8  In-person  Apples
# 9     Remote  Apples
